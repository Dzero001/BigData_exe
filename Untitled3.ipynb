# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hypertension_all.csv')
df
# Out:
#     zone     province    2016    2017    2018  population
# 0      0      Bangkok  133085  128883  136418     5575104
# 1      1   Chiang Mai   33566   33071   35546     1620100
# 2      1      Lamphun    5616    5406    6992      403330
# 3      1      Lampang   19044   21150   22130      742078
# 4      1        Phrae   13974   15019   15262      445766
# ..   ...          ...     ...     ...     ...         ...
# 72    12        Trang   15653   16467   17421      641755
# 73    12  Phatthalung   10654   11398   12646      524618
# 74    12      Pattani    7287    7513    7974      712310
# 75    12         Yala    7476    8652    8359      528350
# 76    12   Narathiwat   13131   14736   17594      798098
#
# [77 rows x 6 columns]

# %%
df['2018'].hist(bins=[0,20000, 40000, 60000, 80000, 100000])
# Out:
# <Axes: >

# %% [markdown]
# This chart shows the distribution of patients with hypertension

# %%
plt.style.use('ggplot')
df['2018'].hist()
# Out:
# <Axes: >

# %%
df.set_index('province') ['2018'].head(10).plot.bar()
# Out:
# <Axes: xlabel='province'>

# %%
df.set_index('province') [['2016', '2017', '2018']].head(10).plot.bar(stacked=True)
# Out:
# <Axes: xlabel='province'>

# %%
df = pd.read_csv('hypertension_all.csv')
zone2 =df[df['zone'] == 2]
zone2.set_index('province') [['2016', '2017', '2018']].head(10).plot.bar(stacked=True)
# Out:
# <Axes: xlabel='province'>

# %%
df.plot.scatter(x='2018', y='population')
# Out:
# <Axes: xlabel='2018', ylabel='population'>

# %%
ax=df.plot.scatter(x='2018', y='population')
ax.set_xlabel('Number of patient with hypertensin, year 2018')
plt.show()

# %%
ax= df[df['zone']!= 0].plot.scatter(x='2018', y='population')
ax.set_xlabel('Number of patients with hypertension, year 2018')
# Out:
# Text(0.5, 0, 'Number of patients with hypertension, year 2018')

# %%
df = pd.read_csv('diag_code_2016.csv')
df['DATE_DIAG'] = pd.to_datetime(df['DATE_DIAG'])
df=df[df['DATE_DIAG'] < '2016-03-01']
df= df.set_index('DATE_DIAG')
df
# Out:
#              A   B   C  D    E  F  G    I   J   K   M   N
# DATE_DIAG
# 2016-01-01   4   0   9  0   80  0  0  153  87   2   2   8
# 2016-01-02   2   0   2  0    6  0  0   27  11   0   2   3
# 2016-01-03   0   0   2  0    9  0  0   33   2   2   0   4
# 2016-01-04   6  11  25  0   49  0  0  196  12   5  15   4
# 2016-01-05   5   4  19  0   48  0  0  154   6   3   9   5
# 2016-01-06   4   7  24  0   53  0  0  144  20   3  11   7
# 2016-01-07   3   7  30  0   72  0  0  158  21   9  17   8
# 2016-01-08  17   7  29  0   46  0  0  133  13   4  11   2
# 2016-01-09   0   0   4  0    6  0  0   20   2   2   1   1
# 2016-01-10   1   1   5  0    5  0  0   24   6   2   0   1
# 2016-01-11   3   5  25  0   73  0  0  134  10   1  13  10
# 2016-01-12   9   8  25  0   61  0  0  153   8   3  13  14
# 2016-01-13  13   2  15  0   42  0  0  119  11   2   5   3
# 2016-01-14   5   4  20  0   45  0  0  133  43   3  15   4
# 2016-01-15   0   4  23  0   39  0  0  131  42   7   5   4
# ...

# %%
df[['I', 'J']].plot.line(figsize=(10,5))
# Out:
# <Axes: xlabel='DATE_DIAG'>

# %%
df[['I', 'J']].plot.area(alpha=0.4, figsize=(10,5))
# Out:
# <Axes: xlabel='DATE_DIAG'>

# %%
df = pd.read_csv('diag_code_2016.csv')
df['DATE_DIAG'] = pd.to_datetime(df['DATE_DIAG'])
thirdperiod =df[(df['DATE_DIAG'] >= '2016-07-01') & (df['DATE_DIAG']<= '2016-09-30')]


thirdperiod[['A', 'B', 'C' , 'G']].plot.line(figsize=(10,5))
# Out:
# <Axes: >

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 85.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# __Boxplot 3__

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('hypertension_all.csv')
df[['2016','2017','2018']].plot.box()
plt.style.use('ggplot')

# %%
df=pd.read_csv('hypertension_all.csv')
df
# Out:
#     zone     province    2016    2017    2018  population
# 0      0      Bangkok  133085  128883  136418     5575104
# 1      1   Chiang Mai   33566   33071   35546     1620100
# 2      1      Lamphun    5616    5406    6992      403330
# 3      1      Lampang   19044   21150   22130      742078
# 4      1        Phrae   13974   15019   15262      445766
# ..   ...          ...     ...     ...     ...         ...
# 72    12        Trang   15653   16467   17421      641755
# 73    12  Phatthalung   10654   11398   12646      524618
# 74    12      Pattani    7287    7513    7974      712310
# 75    12         Yala    7476    8652    8359      528350
# 76    12   Narathiwat   13131   14736   17594      798098
#
# [77 rows x 6 columns]

# %% [markdown]
# __Activity 3__

# %%
df['p_rate_2016']=df['2016']*100000/df['population']
df['p_rate_2017']=df['2017']*100000/df['population']
df['p_rate_2018']=df['2018']*100000/df['population']
df.set_index('province') [['p_rate_2016','p_rate_2017','p_rate_2018']].head(10).plot.bar()
# Out:
# <Axes: xlabel='province'>

# %%
df=pd.read_csv('hypertension_all.csv')
by_zone=df.groupby('zone')
by_zone[['2016','2017','2018']].sum().plot.bar()
by_zone.describe()
# Out:
#       2016                                                              \
#      count           mean           std       min        25%       50%
# zone
# 0      1.0  133085.000000           NaN  133085.0  133085.00  133085.0
# 1      8.0   15529.500000   9571.166372    2627.0   11397.00   14470.5
# 2      5.0   15064.400000   4900.217730    8507.0   12498.00   14643.0
# 3      5.0   13958.400000   6504.347877    7487.0   11664.00   12469.0
# 4      8.0   13871.625000   4059.735246    7675.0   10639.75   15124.5
# 5      8.0   15131.000000   6117.042866    5867.0   10694.00   16013.0
# 6      8.0   13331.125000   6932.746404    5690.0    8322.25   11955.5
# 7      4.0   26019.500000  12984.974201   18061.0   19161.25   20304.0
# 8      7.0   12535.571429   8142.120155    5152.0    6154.00    9626.0
# 9      4.0   32537.000000  15091.417848   20132.0   23186.75   28022.0
# 10     5.0   15612.200000  12544.454659    4335.0    7168.00   11693.0
# ...

# %%
df=pd.read_csv('hypertension_all.csv')
df2= df[['zone','2018']]
df2.groupby('zone').sum().plot.pie(y='2018')
# Out:
# <Axes: ylabel='2018'>

# %%
df=pd.read_csv('chronic_2016_90_all.csv')
df
# Out:
# C:\Users\6708142\AppData\Local\Temp\ipykernel_1216\4284137253.py:1: DtypeWarning: Columns (1,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('chronic_2016_90_all.csv')
#         HOSPCODE    PID   DATE_DIAG CHRONIC  HOSP_DX  HOSP_RX  DATE_DISCH  \
# 0           9435  10002  2016-01-21     I10  10745.0  10745.0  0000-00-00
# 1           9435  10007  2013-08-30     I10      NaN  10745.0  0000-00-00
# 2           9435  10019  2013-08-29     I10      NaN  10745.0  0000-00-00
# 3           9435  10031  2016-03-31    E119    856.0   9435.0  0000-00-00
# 4           9435  10036  2009-03-10    E119  10745.0   9435.0  0000-00-00
# ...          ...    ...         ...     ...      ...      ...         ...
# 642471     99782    996  2011-04-24     J46      NaN      NaN  0000-00-00
# 642472     99782   9964  2009-06-29     I10      NaN      NaN  2012-02-01
# 642473     99782    997  2008-07-16     I10      NaN      NaN  0000-00-00
# ...

# %%
df['CHRONIC'].value_counts().head(10).plot.bar()
# Out:
# <Axes: xlabel='CHRONIC'>
